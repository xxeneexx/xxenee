# %%
import mod1

mod1.add(3,4)
mod1.sub(4,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mod1
#       3 mod1.add(3,4)
#       4 mod1.sub(4,3)
#
# ModuleNotFoundError: No module named 'mod1'

# %%
from mod1 import

print(add(3,4))
print(sub(4,3))

# %%
from mod1 import *

print(add(10,10)) #추천안함

# %%
frome mod1 import add

add(3,4)
