# %%
# pip install
# !pip3 install SomePackage #맥은 pip아니고pip3 지우는건 pip unstall SomePackge
 #터미널에 해도됨
# Out:
# zsh:1: command not found: pip

# %%
#pip install 패키지명 -> 설치
#pip unintall 패키지명 -> 삭제
#pip install 패키지명 == 버전 ->특정버전을 설치 (버전을 지정해서 설치해야함)
#pip list ->설치된 패키지 리스트 확인

# %%
# !pip3 install Faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.4 MB/s  0:00:00
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
#더미데이터 만들때 이렇게하면됨
# from faker import Faker    ->#Faker은 클래스명 / from faker import대신 import faker로 해도됨
import faker 
# fake = Faker()
# fake.name()
# fake.address()

# for _ in range(10):
#     print(fake.name())
a = faker.Faker()
a.name
# Out:
# Gabrielle Jackson
# Tiffany Taylor
# Michael Harrison
# Miss Madeline Chang MD
# Travis Wong
# Kevin Smith
# Daniel Sanchez
# Nicole Moran
# Richard Dickson
# Michelle Hopkins
