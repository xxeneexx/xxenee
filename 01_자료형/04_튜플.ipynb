# %%
#튜플은 어떻게 만들까?
#()소괄호로 만든다
#순서 있음
#수정 불가능
#iterable(인터러블) 넣으면 튜플 만들어줌 
#인터러블:안에 여러개있고 차례대로 꺼낼수 있는 자료형 ex)리스트, 문자열, 딕셔너리, 집합,range 등
#이미 튜플이면 그대로 반환
#튜플 안에 리스트는 변경 가능 t = (1, [2,3])
t1=()
t2=(1, )   #요소 1개짜리 튜플 만들때는 콤마 반드시 찍어야함/ 콤마 찍지 않으면 그냥 정수 1로 인식
t3=(1,2,3)
t4=1,2,3   #소괄호 생략 가능 그래도 튜플로 인식한다
t5=("a","b",("ab","cd"))

a=list()
b=tuple()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4 t3=(1,2,3)
#       5 t4=1,2,3
# ----> 6 t5("a","b",("ab","cd"))
#       8 a=list()
#       9 b=tuple()
#
# NameError: name 't5' is not defined

# %%
t1=(1,2,"a","b")

#튜플 요소값을 삭제하려 할때  ->지울 수 없음
del t1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 t1=(1,2,"a","b")
#       3 #튜플 요소값을 삭제하려 할때  ->지울 수 없음
# ----> 4 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1=(1,2,"a","b")

#튜플 요소값을 변경하려 할때--> 변경할 수 없다
t1[1]=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 t1=(1,2,"a","b")
#       3 #튜플 요소값을 변경하려 할떄
# ----> 4 t1[1]=4
#
# TypeError: 'tuple' object does not support item assignment

# %%
#인덱싱하기
#( ) = 튜플 만드는 기호,  [ ] = 위치 접근(인덱싱) 
#요소 꺼낼때는 [ ]사용 ex)리스트, 튜플, 문자열 등
t1=(1,2,"a","b")
t1[2]
# Out:
# 'a'

# %%
#슬라이싱하기
#start는 시작 인덱스(포함), end는 끝 인덱스(제외)를 의미합니다.

t1=(1,2,"a","b") #요소는 4개 인덱스는 0,1,2,3 
t1[2:4]

#인덱스 2부터 4직전까지 (2,3) 요소 꺼내기
# Out:
# ('a', 'b')

# %%
#튜플 더하기 
t1=(1,2,"a","b")
t2=(3,4)
t1+t2
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
#튜플 곱하기 
t2=(3,4)
t2*3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
#튜플 길이 구하기 
t1=(1,2,"a","b")
len(t1)
# Out:
# 4
