# %%
#1번부터 19번까지 질문에 맞는 문제를 풀어주세요.

1. https://himzei.com
 회원기입하고 자기소개를 작성해해주세요 (각오, MBTI, 파이썬으로 구현하고 싶은 것 등)

2. 파이썬은 어떤 종류의 프로그래밍 언어인가? 다음 빈칸을 채우시오.
- 파이썬은 ( ① ) 언어로, 코드를 한 줄씩 읽어서 바로 실행하는 ( ② )가 필요하다.

- 인터프리터

3. 파이썬 공식 다운로드 사이트 주소를 쓰시오, 설치 시 패스옵션을 체크해야 하는 이유와 안 했을 경우 어떻게 해야 하는지 서술하시오.
- https://www.python.org/
- PATH 옵션을 체크하여야 CMD에서 Python 실행 가능함 안했을경우 환경변수 설정으로 재설정을 할 수 있지만 하는 방법이 복잡함.

4. 파이썬 설치 후, 설치가 제대로 되었는지 확인하는 명령어를 쓰시오.
- 명령 프롬프트(터미널)에서: Python --version 실행

5. 다음 중 파이썬의 특징으로 옳은 것을 모두 고르시오.
① 무료이며 오픈소스이다
② 컴파일 언어이다
③ 다양한 운영체제에서 실행 가능하다
④ 문법이 복잡하여 배우기 어렵다
⑤ 풍부한 라이브러리를 제공한다

- 1번, 3번, 5번

6. 명령 프롬프트(터미널)에서 파이썬 대화형 모드로 진입하는 명령어를 쓰시오.
- Python 입력

7. 대화형 모드에서 빠져나오는 방법 2가지를 쓰시오.
- exit, quit

8. 대화형 모드에서 `>>>` 기호는 무엇을 의미하는가?
- Python 대화형 모드로 진입한 상태

9. 파이썬 파일의 확장자는 무엇이며, 이 파일을 실행하는 명령어를 쓰시오.
(파일명 예시 : test)
- 확장자: test.py
- 실행 명령어: python test.py

10. 현재 폴더에 `hello.py` 파일이 있을 때, 이를 실행하는 명령어를 쓰시오. 

- python hello.py

11. 다음 상황에서 파일을 실행하는 명령어를 쓰시오.
- 현재 위치: C:\Users\student
- 파일 위치: C:\Users\student\projects\mycode.py

- cd projects 명령어 실행 후 python mycode.py 실행
- python projects\mycode.py
- python C:\Users\student\projects\mycode.py

12. 다음 상황에서 파일을 실행하는 명령어를 쓰시오.
- 현재 위치: C:\Users\student\documents
- 파일 위치: C:\Users\student\projects\test.py

- cd .. 명령어 실행 후 cd projects 실행 후 python test.py 실행
- cd .. 명령어 실행 후 python projects\test.py
- python C:\Users\student\projects\test.py

13. 절대 경로(Absolute Path)와 상대 경로(Relative Path)의 차이를 설명하시오.

- 절대 경로는 파일의 위치를 전체 다 표시하는 경로
- 상대 경로는 현재 작업중인 위치를 기준으로 표시하는 경로
- 위 문제 답안을 예시로 들자면
   - python C:\Users\student\projects\test.py = 절대경로
   - - cd .. 명령어 실행 후 cd projects 실행 후 python test.py 실행 = 상대경로

14. 다음 중 절대 경로에 해당하는 것을 모두 고르시오.
① hello.py
② ./scripts/main.py
③ C:\Users\student\code\app.py
④ ../data/file.txt
⑤ /home/user/projects/test.py

- 3번, 5번

15. 상대 경로에서 사용하는 다음 기호의 의미를 쓰시오.
(1) .  (점 하나) - 현재 dir
(2) .. (점 두 개) - 상위 dir
(3) /  또는  \ - dir 구분자

16. 명령 프롬프트에서 현재 디렉토리를 확인하는 명령어를 쓰시오. 

- cd
- cd .

17. 명령 프롬프트에서 디렉토리를 이동하는 명령어를 쓰시오.
예: projects 폴더로 이동

- cd
- 예 : cd projects

18.  IDE란 무엇의 약자이며, 한글로 무엇이라고 하는지 쓰시오. 또한 IDE의 역할을 간단히 설명하시오.

- IED : Integrated Development Environment
- 통합 개발 환경
- 작성한 코드 실행, 디버깅등을 통합적으로 할 수 있게 해주는 프로그램

19. 다음 중 파이썬 개발에 사용할 수 있는 IDE/에디터를 모두 고르시오.
① Visual Studio Code
② PyCharm
③ Photoshop
④ Sublime Text
⑤ IDLE
⑥ Excel
⑦ Jupyter Notebook

- 1, 2, 4, 5, 7

### 숫자 자료형
## ※ 모든 코드는 직접 파이썬에서 실행하여 결과를 확인한 후 작성하세요.

1. / 연산자와 // 연산자의 차이점을 설명하시오.

- / 연산자는 나눗셈의 값을 구하는 연산자
- // 연산자는 나눗셈의 몫을 구하는 연산자

2. 다음 코드의 실행 결과를 쓰시오.
print(17 % 5)   - 2                        
print(23 % 7)   - 2                      
print(100 % 3)  - 1

3. % 연산자는 무엇을 구하는 연산자인지 설명하고, 실생활에서 활용할 수 있는 예시를 하나 들어 쓰시오.

- % 연산자는 나눗셈의 나머지를 구하는 연산자
- 축구 동호회 당일 경기 참여자가 27명일 때 교체 인원이 몇명인지 파악할 때

4. ** 연산자가 의미하는 것을 설명하시오.

- 제곱 연산

5. 다음 조건에 맞게 코드를 작성하시오.
- 변수 x에 8진수 25를 저장
- 변수 y에 16진수 FF를 저장
- x와 y의 합을 출력

- x = 0o25
  y = 0xFF
  print(x + y)

6. 원의 넓이를 계산하는 프로그램을 작성하시오.
- 반지름(r)은 변수로 저장 (예: r = 5)
- 원주율(pi)은 3.14159를 사용
- 공식: 넓이 = π × r²

- r = 5
  r **= 2
  pi = 3.14159
  area = r * pi
  print(area)

7. 복리 이자를 계산하는 프로그램을 작성하시오.
- 원금(principal): 1,000,000원
- 연이율(rate): 5% (0.05)
- 기간(years): 3년
- 공식: 최종금액 = 원금 × (1 + 연이율)^기간

- pri = 1_000_000
  rate = 1.05
  years = 3
  rate **= years
  f_pri = pri * rate
  print(f_pri)
    
    
### 문자 자료형
## ※ 모든 코드는 직접 파이썬에서 실행하여 결과를 확인한 후 작성하세요.

1. 파이썬에서 문자열을 만드는 4가지 방법을 쓰시오 

- ', ", ''', """

2. 다음 문자열을 출력하시오
- Python's favorite food is perl

- print("Python's favorite food is perl")
- print('Python\'s favorite food is perl')
- print("""Python's favorite food is perl""")
- print('''Python's favorite food is perl''')


3. 다음 문자열을 출력하시오 
- "Python is very eash" he says

- print("\"Python is very easy.\" he says.")
- print('"Python is very easy." he says.')
- print(""""Python is very easy." he says.""")
- print('''"Python is very easy." he says.''')


4. 다음 코드에서 에러가 발생하는 이유를 설명하고 올바르게 수정하시오  
- msg = 'It's a beautiful day 

- It's의 '에서 문자열이 끝났다고 인식하여 오류 발생
- msg = "It's a beautiful day"

5. 다음 이스케이프 코드의 의미를 쓰시오. (5점)
(1) \n : 줄바꿈
(2) \t : Tab 기능
(3) \\ : \ 를 문자로 인식
(4) \' : ' 를 문자로 인식
(5) \" : " 를 문자로 인식

6. 다음 코드의 실행 결과를 쓰시오. 
- print("C:\\Users\\python\\test.py")

- C:\Users\python\test.py

7. len() 함수는 무엇을 반환하는지 설명하시오

- 문자열의 길이 (문자의 개수)
- ex) a = '1234'
      len(a)

      4

8. 문자열 인덱싱에서 a[-1]이 의미하는 것을 설명하시오.

- 문자열 마지막에 있는 문자
- ex) a = '1234'
      a[-1]
      
      4

9. 다음 코드의 실행 결과를 쓰시오. (4점)
a = "Life is too short, You need Python"         
print(a[12])                                     
print(a[-5])

- s
  y

10. 다음 코드의 실행 결과를 쓰시오.
a = "Life is too short, You need Python"         
print(a[0:4])     

- Life                     

11. 문자열 "Hello World"에서 인덱싱을 이용하여 "WH"를 출력하는 코드를 작성하시오

s = "Hello World"
w = s[-5]
h = s[0]
wh = w + h
print(wh)
@xxeneexx
Comment

# %%
# Out:
#   Cell In[6], line 3
#     1. / 연산자와 // 연산자의 차이점을 설명하시오.
#                       ^
# SyntaxError: invalid syntax

# %%
#
# Out:
# 276
